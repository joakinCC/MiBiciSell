# %% [markdown]
# # MiBici

# %% [markdown]
# MiBici es un sistema de transporte público creado por el gobierno de Jalisco donde puedes tomar y/o dejar una bicicleta.
# El sistema cuenta con una red de 236 bahías alrededor de 2000 bicicletas y más de 50,000 usuarios.
# Dada la información anterior he pensado que sería un excelente negocio para el 2019 vender aguas frescas a los ciclistas.
#
# Para lograr mi objetivo necesito conocer el comportamiento de los usuarios de MiBici así como la temperatura para poder determinar los puntos en los cuales pueda tener una mayor venta.

# %%
import pandas as pd
import folium

# %% [markdown]
# # DATOS

# %% [markdown]
# ## Estaciones MiBici

# %%
MiBici_Estaciones = pd.read_csv(r'C:/Users/CJO2MX/Documents/MiBiciSell/Data/MiBici/nomenclaturaMiBici.csv', encoding='latin-1')
MiBici_Estaciones.head()
# Out:
#    id                                           name     obcn  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  GDL-001
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  GDL-002
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  GDL-003
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  GDL-004
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  GDL-005
#
#            location   latitude   longitude      status
# 0  POLÍGONO CENTRAL  20.666378 -103.348820  IN_SERVICE
# 1  POLÍGONO CENTRAL  20.667228 -103.366000  IN_SERVICE
# 2  POLÍGONO CENTRAL  20.667690 -103.368252  IN_SERVICE
# 3  POLÍGONO CENTRAL  20.691750 -103.362550  IN_SERVICE
# 4  POLÍGONO CENTRAL  20.681151 -103.338863  IN_SERVICE

# %% [markdown]
# Dentro del dataframe vemos que en la columan status solo nos importan aquellas estaciones "IN_SERVICE"

# %%
MiBiciEstaciones = MiBici_Estaciones[MiBici_Estaciones.status == 'IN_SERVICE']

# %%
MiBiciEstaciones = MiBiciEstaciones[['id','name','latitude', 'longitude']]
MiBiciEstaciones = MiBiciEstaciones.reset_index(drop=True)

# %%
MiBiciEstaciones.head(200)
# Out:
#       id                                           name   latitude   longitude
# 0      2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  20.666378 -103.348820
# 1      3     (GDL-002) C. Colonias  / Av.  Niños héroes  20.667228 -103.366000
# 2      4          (GDL-003) C. Vidrio / Av. Chapultepec  20.667690 -103.368252
# 3      5           (GDL-004) C. Ghilardi /C. Miraflores  20.691750 -103.362550
# 4      6  (GDL-005) C. San Diego /Calzada Independencia  20.681151 -103.338863
# 5      8   (GDL-006) C. Venustiano Carranza /C. Reforma  20.680752 -103.344380
# 6      9   (GDL-007)C. Epigmenio Glez./Av. Cristobal C.  20.666771 -103.350562
# 7     10    (GDL-008) C. J. Angulo / C. González Ortega  20.681871 -103.350396
# 8     11      (GDL-009) Calz. Federalismo/ C. J. Angulo  20.681984 -103.353835
# 9     12    (GDL-010) C. Cruz verde / C. Joaquin Angulo  20.681786 -103.357267
# 10    13              (GDL-011) C. Garibaldi / C. Frías  20.681081 -103.360099
# 11    14      (GDL-012) C. Joaquín Angulo / C. Ghilardi  20.681989 -103.362920
# 12    15             (GDL-013) C. Vidrio  / C. Marsella  20.667623 -103.370499
# 13    16  (GDL-014)C. J. Angulo/C. José Clemente Orozco  20.682059 -103.365969
# 14    17  (GDL-015) C. Herrera y Cairo /C. Pedro Buzeta  20.683191 -103.369349
# 15    18  (GDL-016)C. Bernardo de Balbuena/C. J. Angulo  20.682007 -103.372642
# 16    19  (GDL-017) Av. México /C. Bernardo de Balbuena  20.679086 -103.372841
# 17    20    (GDL-018) Av. México / C. Manuel M. Diéguez  20.679296 -103.370658
# 18    21    (GDL-019)  C. Juan Manuel / C. Andrés Terán  20.678835 -103.368045
# 19   254  (GDL-020) C. General Coronado / C.Juan Manuel  20.678480 -103.365103
# 20    23       (GDL-021) C. Nicolás Romero / C. Reforma  20.679660 -103.362224
# 21    24  (GDL-022)C. San Felipe /C. Enrique D. de León  20.679389 -103.359130
# 22    25             (GDL-023) C. Jesús / C. San Felipe  20.679309 -103.356281
# 23    26    (GDL-024) Av.  Federalismo / C. Juan Manuel  20.678777 -103.354035
# 24    27      (GDL-025) C. Reforma / C. González Ortega  20.680227 -103.350146
# 25    28           (GDL-026) C. Pedro Loza / C. Reforma  20.680478 -103.348377
# 26    29             (GDL-027) C. Belén / C. San Felipe  20.679861 -103.345198
# 27    30  (GDL-028) C. Gregorio Dávila /C. Manuel Acuña  20.684187 -103.361130
# 28    31          (GDL-029)Calz. Indep. /C. Juan Manuel  20.679505 -103.339753
# 29    32         (GDL-030) C. Pedro Moreno/ C. Progreso  20.675461 -103.367501
# ..   ...                                            ...        ...         ...
# 170  238       (GDL-171) C. Maquinistas / C. San Rafael  20.646100 -103.310200
# 171  239           (GDL-172) C. Chamizal / Av. Rio Nilo  20.644340 -103.306780
# 172  240       (GDL-173) C. Caballerango / C. Caporales  20.645040 -103.305180
# 173  241   (GDL-174) C. Juan de Zumárraga / Av. Tepeyac  20.664100 -103.400300
# 174  242             (GDL-175) C. Ermita / C. San Uriel  20.662341 -103.398134
# 175  243  (GDL-176) C. San Bonifacio/ Paseo Benedictino  20.672762 -103.397625
# 176  244    (GDL-177) C. Fray Fco Frejes / C. Fco Zarco  20.686690 -103.376570
# 177  246  (GDL-178) C Salvador Quevedo/C López Portillo  20.685108 -103.333746
# 178  247  (GDL-179) C. Monte Cáucaso / C. Sierra Nevada  20.687950 -103.333430
# 179  248  (GDL-180) C. Montes Pirineos/Salvador Quevedo  20.686920 -103.334670
# 180  249  (GDL-181) C.Ignacio Rmrz / Av Plan de San Lui  20.697050 -103.363220
# 181  255  (GDL-182) C. General Coronado / C. Manuel Acu  20.684164 -103.364829
# 182  256  (GDL-183) Calz. Independencia / Av. Niños Hér  20.663986 -103.348078
# 183  257           (GDL-184) Ingreso Cucei / Revolución  20.659590 -103.324471
# 184  258         (GDL-185) Silverio García / Revolución  20.663180 -103.329420
# 185  259           (GDL-186) C. Argentina / Av. Francia  20.664290 -103.362800
# 186  260           (GDL-187) Ramón Corona / Revolución*  20.672840 -103.347180
# 187  261              (GDL-188) La Presa/ Ávila Camacho  20.709280 -103.370150
# 188  262                (GDL-189) Analco / Constitución  20.669200 -103.341160
# 189  263                 (GDL-190) Anahuac / Revolución  20.670800 -103.343850
# 190  264              (GDL-191) Plaza de los mariachis*  20.674400 -103.341230
# 191  265                 (GDL-192) A- 1 /Ávila Camacho*  20.706560 -103.365640
# 192  266              (GDL-193) Hawai / Nicolás Romero*  20.702110 -103.359960
# 193  267      (GDL-194) Ramón López Velarde/ Revolución  20.650480 -103.309990
# 194  268                (GDL-195) Ramón Corona/ Juárez*  20.675290 -103.346560
# 195  269    (GDL-196) Esmeralda / Calzada Independencia  20.683610 -103.337560
# 196  270                (GDL-197) Río Nilo / Revolución  20.645170 -103.303130
# 197  271                   (GDL-198) Alcalde /Hospital*  20.685040 -103.347960
# 198  272                (GDL-199) Alcalde/ Jesús García  20.689100 -103.348060
# 199  274              (GDL-201) Gonzalo Curiel /Alcalde  20.694420 -103.344740
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Mapa

# %%
locations = MiBiciEstaciones[['latitude', 'longitude']]
locationlist = locations.values.tolist()

# %%
map = folium.Map(location=[20.6871392,-103.3881409], zoom_start=12)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=MiBiciEstaciones['name'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Gas_Estaciones = pd.read_csv(r'C:/Users/CJO2MX/Documents/MiBiciSell/Data/Pollution/diccionario.csv')

# %%
Gas_Estaciones
# Out:
#    id         name  latitude  longitude
# 0   0     Atemajac     20.72    -103.36
# 1   1       Centro     20.67    -103.33
# 2   2  Las aguilas     20.63    -103.42
# 3   3   Las Pintas     20.58    -103.33
# 4   4  Loma Dorada     20.63    -103.26
# 5   5    Miravalle     20.61    -103.34
# 6   6      Oblatos     20.70    -103.30
# 7   7     Santa Fe     20.53    -103.38
# 8   8  Tlaquepaque     20.64    -103.31
# 9   9     Vallarta     20.68    -103.40

# %%
locations_Gas = Gas_Estaciones[['latitude', 'longitude']]
locationlist_Gas = locations_Gas.values.tolist()

# %%
map = folium.Map(location=[20.6871392,-103.3881409], zoom_start=12)
for point in range(0, len(locationlist_Gas)):
    folium.Marker(locationlist_Gas[point], popup=Gas_Estaciones['name'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Vamos a unir los dataframe con el fin de poder representar todos los puntos en el mismo mapa y agregar una nueva columna
# la cual determine si los datos corresponde a una bahía o una estación de gas.

# %%
MiBiciEstaciones['fuente'] = 'MiBici'
Gas_Estaciones['fuente'] = 'Gas'

# %%
MiBici_Gas = [MiBiciEstaciones, Gas_Estaciones]
MiBici_Gas = pd.concat(MiBici_Gas)

# %%
MiBici_Gas.head()
# Out:
#    id                                           name   latitude   longitude  \
# 0   2  (GDL-001) C. Epigmenio Glez./ Av. 16 de Sept.  20.666378 -103.348820
# 1   3     (GDL-002) C. Colonias  / Av.  Niños héroes  20.667228 -103.366000
# 2   4          (GDL-003) C. Vidrio / Av. Chapultepec  20.667690 -103.368252
# 3   5           (GDL-004) C. Ghilardi /C. Miraflores  20.691750 -103.362550
# 4   6  (GDL-005) C. San Diego /Calzada Independencia  20.681151 -103.338863
#
#    fuente
# 0  MiBici
# 1  MiBici
# 2  MiBici
# 3  MiBici
# 4  MiBici

# %% [markdown]
# reindexamos con la finalidad de poder mostrar los puntos en el mapa

# %%
MiBici_Gas = MiBici_Gas.reset_index(drop=True)

# %%
locations_MiBiciGas = MiBici_Gas[['latitude', 'longitude']]
locations_MiBiciGas = locations_MiBiciGas.values.tolist()

# %%
map = folium.Map(location=[20.6871392,-103.3881409], zoom_start=12)
for point in range(0, len(locations_MiBiciGas)):
    folium.Marker(locations_MiBiciGas[point],
                  popup=MiBici_Gas['name'][point],
                  icon=folium.Icon(color='green' if MiBici_Gas['fuente'][point] == 'MiBici' else 'blue',
                                    prefix='fa', icon='circle')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# En el mapa anterior (3) se observa en marcador verde las estaciones de MiBici y en azul las estaciones de gas.
# La finalidad del projecto es vender agua...Se buscara la variacion de temperatura en 2017 y 2018 en Guadalajara y Zapopan
# para validar los datos de temperatura de nuestro dataset
